# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página de libros más vendidos de Book Depository, y para lograr esto, también tendrá que hacer uso de un poco de pandas principalmente..

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\jamf1\appdata\local\programs\python\python37\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jamf1\appdata\local\programs\python\python37\lib\site-packages (from beautifulsoup4) (2.3.1)

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\jamf1\appdata\local\programs\python\python37\lib\site-packages (4.8.0)

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\jamf1\appdata\roaming\python\python37\site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jamf1\appdata\roaming\python\python37\site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jamf1\appdata\roaming\python\python37\site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jamf1\appdata\roaming\python\python37\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jamf1\appdata\roaming\python\python37\site-packages (from requests) (2.0.12)

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.bookdepository.com/es/bestsellers"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <link rel="preconnect" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<link rel="dns-prefetch" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<script type="text/javascript">\n        function csmWidgetStart(widgetName) {\n            if (typeof uet == \'function\') {\n                uet(\'bb\', widgetName, {wb: 1});\n            }\n        }\n        function csmWidgetEnd(widgetName) {\n            if (typeof uet == \'function\') {\n                uex(\'ld\', widgetName, {wb: 1});\n            }\n        }\n    </script>\n    <noscript>\n        <style>\n            .hide-when-no-js {\n                display: none !important;\n            }\n\n            .show-when-no-js {\n                display: block !important;\n            }\n        </style>\n    </noscript>\n\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n<meta name="copyright" content="&copy;2020 Book Depository Ltd." />\n<meta name="author" content="Book Depository" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1">\n<meta name="google-site-verification" content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" />\n<meta name="msvalidate.01" content="D45E907CC9A963F78BD3129AAAAFE4F0" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge; charset=UTF-8"> <meta name="description" content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." />\n    <meta name="keywords" content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" />\n\t<meta name="Revisit-After" content="30 days" />\n\t<link rel="canonical" href="https://www.bookdepository.com/es/bestsellers" />\n<link rel="alternate" hreflang="x-default" href="https://www.bookdepository.com/bestsellers" />\n\t<link rel="alternate" hreflang="en" href="https://www.bookdepository.com/bestsellers" />\n\t<link rel="alternate" hreflang="es" href="https://www.bookdepository.com/es/bestsellers" />\n\t<link rel="next" href="/es/bestsellers?page=2" />\n\t<title>\n\tBestselling books online with free delivery at Book Depository</title>\n\n<!-- Styles -->\n<link rel="shortcut icon" type="image/ico" href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" />\n<link rel="apple-touch-icon-precomposed" href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" />\n<link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/common.css" onload="csmWidgetEnd(\'css-download\');">\n<!--[if lte IE 9]>\n<link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/ie/common.css">\n<![endif]-->\n\n<script type="text/javascript">\n    csmWidgetStart(\'icons-download\');\n</script>\n<link rel="preload" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/fonts/bdicons.woff" as="font" type="font/woff2" crossorigin onload="csmWidgetEnd(\'icons-download\');">\n\n<script type="text/javascript">\n    csmWidgetStart(\'font-download\');\n</script>\n\n<script type="text/javascript">\n    csmWidgetStart(\'css-download\');\n</script>\n<script type="text/javascript">\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n        (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n        m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    \n    window.ga(\'create\', \'UA-41807899-1\', \'www.bookdepository.com\', {\n        \'allowLinker\': true,\n        \'storage\': \'none\'\n    });\n    \n\n    function registerPageView() {\n        window.ga(\'send\', \'pageview\');\n    }\n    document.addEventListener("DOMContentLoaded", function() {\n        registerPageView();\n    });\n</script>\n\n</head>\n<body class="">\n<div class="cookie-consent">\ ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los libros más vendidos)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." name="description"/>
# <meta content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <link href="https://www.bookdepository.com/es/bestsellers" rel="canonical"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/bestsellers" hreflang="es" rel="alternate"/>
# <link href="/es/bestsellers?page=2" rel="next"/>
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="">
# <div class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>Usamos cookies para mejorar este sitio</h2>
# <p>Las cookies se usan para brindar, analizar y mejorar nuestros servicios, proporcionar herramientas de chat y mostrarte<br/>contenido publicitario relevante. Puedes obtener más información acerca de nuestro uso de cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>aquí</a></p><h2>¿Aceptas las cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Sí</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</a>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Preferencias de cookies</h2>
# <p>Usamos cookies y herramientas similares que son necesarias para facilitarle las compras, incluidas las que usan los terceros autorizados (colectivamente, "cookies"), para los fines que se describen a continuación.
#      <br/>Para obtener más información acerca de cómo usamos las cookies (y cómo las usan los terceros autorizados) y cómo cambiar tu configuración, consulta el <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>. Las elecciones que realices aquí se aplicarán a la interacción con este servicio en este dispositivo.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Indispensable</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>Usamos cookies para brindar nuestros servicios,</span>
# <div>
# <div class="additionalInfo wrapping-space">por ejemplo, para realizar un seguimiento de los artículos almacenados en tu canasta de compras, prevenir actividades fraudulentas, mejorar la seguridad de nuestros servicios, realizar un seguimiento de tus preferencias específicas (como preferencias de moneda o idioma) y mostrar características, productos y servicios que puedan ser de tu interés. Debido a que usamos cookies para brindarte nuestros servicios, estas no se pueden desactivar cuando se usan con este fin.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Desempeño y analítica</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ACTIVADO</span>
# <span class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si usted lo acepta, usaremos cookies para entender cómo los clientes usan nuestros servicios</span>
# <div>
# <div class="additionalInfo wrapping-space"> (como por ejemplo, medir visitas en nuestra página web) y poder mejorarlos. Por ejemplo, usamos cookies para realizar investigaciones y diagnósticos a fin de mejorar el contenido, los productos y los servicios, y para evaluar y analizar el desempeño de nuestros servicios.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Publicidad</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ACTIVADO</span>
# <span class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si usted lo acepta, usaremos cookies para completar su experiencia de compra, tal y como se describe en el <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>,</span>
# <div>
# <div class="additionalInfo wrapping-space"> para ofrecerle ciertos tipos de anuncios relevantes según tus intereses en Book Depository. Esto incluye utilizar las cookies de terceros para mostrarle y medir anuncios (visite el Aviso sobre Publicidad Basada en los intereses del usuario para entender cómo usamos cookies para mostrarle anuncios basados en sus intereses), medir la efectividad de anuncios y, como parte necesaria para los terceros, para prestarle servicios en nombre de Book Depository.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                 Cancelar</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Guardar configuración</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a></li>
# <li class="mob-nav-account"><a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a></li>
# <li class="mob-nav-account"><a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/es/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/es/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/es/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Buscar libros por palabra clave / título / autor / ISBN" class="text-input" name="searchTerm" placeholder="Buscar libros por palabra clave / título / autor / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Buscar</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 Todas las categorías</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Menú principal</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/es/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/es/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/es/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/es/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/es/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Libros infantiles por edades</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/es/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/es/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/es/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/es/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/es/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/es/bestsellers">Los más vendidos</a></li>
# <li class="mob-nav-shop"><a href="/es/comingsoon">Próximamente </a></li>
# <li class="mob-nav-shop"><a href="/es/top-new-releases">Nuevos lanzamientos</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         Español</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Idiomas</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             Inglés (English)</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Español</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="Español">
# <select id="selectLanguage" name="selectLanguage">
# <option value="en_US">
#                     English</option>
# <option selected="selected" value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/es/bestsellers" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/es/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div class="sidebar">
# <div class="sidebar-section search-filter">
# <h2>Filtrar tu búsqueda</h2>
# <div class="sidebar-section-content search-filter-sidebar">
# <form action="/es/bestsellers" class="filter-menu" method="get">
# <div class="form-group">
# <label for="searchTerm">Palabra clave</label>
# <input class="form-control" name="searchTerm" spellcheck="false" type="text" value=""/>
# </div>
# <input name="searchSortBy" type="hidden" value=""/>
# <input name="category" type="hidden" value=""/>
# <div class="form-group">
# <label for="filter_price">Precio</label>
# <select class="form-control" id="filterPrice" name="price">
# <option label="All" value="">
# 							All</option>
# <option label="Under €15" value="low">
# 							Under €15</option>
# <option label="€15 to €30" value="med">
# 							€15 to €30</option>
# <option label="€30 +" value="high">
# 							€30 +</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_availability">Disponibilidad</label>
# <select class="form-control" id="filterAvailability" name="availability">
# <option label="All" value="">
# 							All</option>
# <option label="In stock (77189)" value="1">
# 							In stock (77189)</option>
# <option label="Pre-order (2312)" value="2">
# 							Pre-order (2312)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_search_lang">Idioma</label>
# <select class="form-control" id="filterLang" name="searchLang">
# <option label="All" value="">
# 							All</option>
# <option label="English (73813)" value="123">
# 							English (73813)</option>
# <option label="French (427)" value="137">
# 							French (427)</option>
# <option label="Spanish (2491)" value="404">
# 							Spanish (2491)</option>
# <option label="German (1602)" value="150">
# 							German (1602)</option>
# <option label="Latin (35)" value="246">
# 							Latin (35)</option>
# <option label="Italian (246)" value="202">
# 							Italian (246)</option>
# <option label="Chinese (237)" value="79">
# 							Chinese (237)</option>
# <option label="Russian (25)" value="365">
# 							Russian (25)</option>
# <option label="Japanese (76)" value="205">
# 							Japanese (76)</option>
# <option label="Dutch; Flemish (9)" value="116">
# 							Dutch; Flemish (9)</option>
# <option label="Afrikaans (1)" value="9">
# 							Afrikaans (1)</option>
# <option label="Albanian (1)" value="13">
# 							Albanian (1)</option>
# <option label="Arabic (34)" value="21">
# 							Arabic (34)</option>
# <option label="Catalan (12)" value="71">
# 							Catalan (12)</option>
# <option label="Cherokee (2)" value="85">
# 							Cherokee (2)</option>
# <option label="Czech (12)" value="101">
# 							Czech (12)</option>
# <option label="Danish (3)" value="103">
# 							Danish (3)</option>
# <option label="English, Old (ca. 450-1100) (1)" value="18">
# 							English, Old (ca. 450-1100) (1)</option>
# <option label="Esperanto (1)" value="125">
# 							Esperanto (1)</option>
# <option label="Estonian (1)" value="126">
# 							Estonian (1)</option>
# <option label="Finnish (27)" value="134">
# 							Finnish (27)</option>
# <option label="Galician (1)" value="155">
# 							Galician (1)</option>
# <option label="Greek, Ancient (to 1453) (4)" value="163">
# 							Greek, Ancient (to 1453) (4)</option>
# <option label="Greek, Modern (1453-) (19)" value="164">
# 							Greek, Modern (1453-) (19)</option>
# <option label="Hawaiian (1)" value="172">
# 							Hawaiian (1)</option>
# <option label="Hebrew (14)" value="173">
# 							Hebrew (14)</option>
# <option label="Hindi (1)" value="177">
# 							Hindi (1)</option>
# <option label="Hungarian (4)" value="183">
# 							Hungarian (4)</option>
# <option label="Icelandic (1)" value="187">
# 							Icelandic (1)</option>
# <option label="Iranian languages (1)" value="200">
# 							Iranian languages (1)</option>
# <option label="Irish (11)" value="154">
# 							Irish (11)</option>
# <option label="Korean (86)" value="231">
# 							Korean (86)</option>
# <option label="Maori (1)" value="270">
# 							Maori (1)</option>
# <option label="Marathi (1)" value="272">
# 							Marathi (1)</option>
# <option label="Multiple languages (19)" value="292">
# 							Multiple languages (19)</option>
# <option label="No linguistic content (6)" value="486">
# 							No linguistic content (6)</option>
# <option label="Norwegian (4)" value="317">
# 							Norwegian (4)</option>
# <option label="Norwegian Bokmål (1)" value="314">
# 							Norwegian Bokmål (1)</option>
# <option label="Persian (6)" value="343">
# 							Persian (6)</option>
# <option label="Polish (319)" value="347">
# 							Polish (319)</option>
# <option label="Portuguese (75)" value="349">
# 							Portuguese (75)</option>
# <option label="Romanian (27)" value="362">
# 							Romanian (27)</option>
# <option label="Sanskrit (1)" value="372">
# 							Sanskrit (1)</option>
# <option label="Scottish Gaelic (6)" value="153">
# 							Scottish Gaelic (6)</option>
# <option label="Serbian (1)" value="375">
# 							Serbian (1)</option>
# <option label="Sinhala; Sinhalese (1)" value="384">
# 							Sinhala; Sinhalese (1)</option>
# <option label="Slovak (1)" value="388">
# 							Slovak (1)</option>
# <option label="Slovenian (3)" value="389">
# 							Slovenian (3)</option>
# <option label="Swedish (103)" value="415">
# 							Swedish (103)</option>
# <option label="Tagalog (1)" value="427">
# 							Tagalog (1)</option>
# <option label="Tamil (9)" value="420">
# 							Tamil (9)</option>
# <option label="Turkish (1)" value="446">
# 							Turkish (1)</option>
# <option label="Ukrainian (23)" value="454">
# 							Ukrainian (23)</option>
# <option label="Undetermined (3)" value="456">
# 							Undetermined (3)</option>
# <option label="Urdu (1)" value="457">
# 							Urdu (1)</option>
# <option label="Welsh (5)" value="468">
# 							Welsh (5)</option>
# <option label="Yiddish (1)" value="476">
# 							Yiddish (1)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="">Formato</label>
# <select class="form-control" id="filterFormat" name="format">
# <option label="All" value="">
# 							All</option>
# <option label="Paperback" value="1">
# 							Paperback</option>
# <option label="Hardback" value="2">
# 							Hardback</option>
# <option label="Audio" value="3">
# 							Audio</option>
# <option label="Baby Books" value="4">
# 							Baby Books</option>
# <option label="Digital" value="5">
# 							Digital</option>
# <option label="Maps" value="6">
# 							Maps</option>
# <option label="Stationery" value="7">
# 							Stationery</option>
# <option label="Toys" value="8">
# 							Toys</option>
# </select>
# </div>
# <div class="form-group padded-btn-wrap">
# <button class="btn btn-primary" type="submit">
# 					Buscar</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="main-content bestseller-page">
# <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filtrar tu búsqueda">Filtrar tu búsqueda</a>
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>
# <div class="head-block">
# <div class="search-info left-content" id="search-info">
#                 Mostrando 1 a 30 de <span class="search-count">1.000</span> resultados</div>
# <div class="right-content">
# <ul class="pagination pagination-sm responsive-pagination">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-top"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# <div class="content-block">
# <div class="block-wrap search no-heading">
# <div class="block">
# <div class="tab-wrap module type-book grid tab--2 tab-active">
# <div class="tab">
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/TommyInnit-Says-Quote-Book-Tom-Simons/9781529427974" itemprop="url">
# <img alt="TommyInnit Says...The Quote Book" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5294/9781529427974.jpg"/>
# </a>
# </div>
# <meta content="9781529427974" itemprop="isbn"/>
# <meta content="TommyInnit Says...The Quote Book" itemprop="name"/>
# <meta content="Tom Simons" itemprop="contributor"/>
# <meta content="Will Gold" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/TommyInnit-Says-Quote-Book-Tom-Simons/9781529427974">
#                     TommyInnit Says...The Quote Book<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Tom-Simons" itemprop="author">Tom Simons</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">13 Oct 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">19,39 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529427974" data-price="19.39" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529427974" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Courtiers-Valentine-Low/9781472290908" itemprop="url">
# <img alt="Courtiers" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4722/9781472290908.jpg"/>
# <div class="savings-splat">
#                         Ahorra<br/>7%</div>
# </a>
# </div>
# <meta content="9781472290908" itemprop="isbn"/>
# <meta content="Courtiers" itemprop="name"/>
# <meta content="Valentine Low" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Courtiers-Valentine-Low/9781472290908">
#                     Courtiers<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Valentine-Low" itemprop="author">Valentine Low</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">06 Oct 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">23,03 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">25,00 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                         Más bajo</a>:
#                                     <span class="price-save">
#                                         23,03 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472290908" data-price="23.03" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781472290908" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Verity-Colleen-Hoover/9781408726600" itemprop="url">
# <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
# </a>
# </div>
# <meta content="9781408726600" itemprop="isbn"/>
# <meta content="Verity" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Verity-Colleen-Hoover/9781408726600">
#                     Verity<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Verity" href="/es/Verity-Colleen-Hoover/9781408726600">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">20 Jan 2022</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">13,64 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="13.64" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179" itemprop="url">
# <img alt="It Starts with Us" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398518179.jpg"/>
# </a>
# </div>
# <meta content="9781398518179" itemprop="isbn"/>
# <meta content="It Starts with Us" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179">
#                     It Starts with Us<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Starts with Us" href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">18 Oct 2022</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">19,14 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398518179" data-price="19.14" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398518179" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824" itemprop="url">
# <img alt="I'm Glad My Mom Died" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9821/9781982185824.jpg"/>
# <div class="savings-splat">
#                         Ahorra<br/>17%</div>
# </a>
# </div>
# <meta content="9781982185824" itemprop="isbn"/>
# <meta content="I'm Glad My Mom Died" itemprop="name"/>
# <meta content="Jennette McCurdy" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
#                     I'm Glad My Mom Died<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Jennette-McCurdy" itemprop="author">Jennette McCurdy</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for I'm Glad My Mom Died" href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">15 Sep 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">23,40 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">28,50 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                         Más bajo</a>:
#                                     <span class="price-save">
#                                         23,31 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781982185824" data-price="23.4" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781982185824" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>
# <meta content="9781471156267" itemprop="isbn"/>
# <meta content="It Ends With Us: The most heartbreaking novel you'll ever read" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Aug 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">13,64 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="13.64" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Loss-Donna-Ashworth/9781785304422" itemprop="url">
# <img alt="Loss" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7853/9781785304422.jpg"/>
# <div class="savings-splat">
#                         Ahorra<br/>33%</div>
# </a>
# </div>
# <meta content="9781785304422" itemprop="isbn"/>
# <meta content="Loss" itemprop="name"/>
# <meta content="Donna Ashworth" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Loss-Donna-Ashworth/9781785304422">
#                     Loss<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Donna-Ashworth" itemprop="author">Donna Ashworth</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">04 Oct 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,68 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">19,00 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                         Más bajo</a>:
#                                     <span class="price-save">
#                                         12,68 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785304422" data-price="12.68" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785304422" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Life-Donna-Ashworth/9781785304446" itemprop="url">
# <img alt="Life" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7853/9781785304446.jpg"/>
# </a>
# </div>
# <meta content="9781785304446" itemprop="isbn"/>
# <meta content="Life" itemprop="name"/>
# <meta content="Donna Ashworth" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Life-Donna-Ashworth/9781785304446">
#                     Life<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Donna-Ashworth" itemprop="author">Donna Ashworth</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">04 Oct 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,68 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785304446" data-price="12.68" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785304446" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
# <img alt="Atomic Habits" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
# </a>
# </div>
# <meta content="9781847941831" itemprop="isbn"/>
# <meta content="Atomic Habits" itemprop="name"/>
# <meta content="James Clear" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                     Atomic Habits<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/James-Clear" itemprop="author">James Clear</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Atomic Habits" href="/es/Atomic-Habits-James-Clear/9781847941831">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Nov 2018</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,75 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
# ...
# <h3 class="title">
# <a href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036">
#                     Red, White &amp; Royal Blue: Collector's Edition<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Casey-McQuiston" itemprop="author">Casey McQuiston</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Red, White &amp; Royal Blue: Collector's Edition" href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">11 Oct 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary" href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036" rel="nofollow">
#                           Notificarme</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268" itemprop="url">
# <img alt="The Thursday Murder Club" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2419/9780241988268.jpg"/>
# </a>
# </div>
# <meta content="9780241988268" itemprop="isbn"/>
# <meta content="The Thursday Murder Club" itemprop="name"/>
# <meta content="Richard Osman" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268">
#                     The Thursday Murder Club<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Richard-Osman" itemprop="author">Richard Osman</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Thursday Murder Club" href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">13 May 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">13,74 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241988268" data-price="13.74" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780241988268" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script></div>
# <div class="foot-block">
# <div class="right-content">
# <ul class="pagination pagination-sm">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-bottom"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/es/newsletter/add">
# <div class="form-group">
# <input aria-label="Dirección de correo electrónico para suscribirte a nuestro Newsletter" class="form-control" name="newsletterEmailAddress" placeholder="Correo electrónico" spellcheck="false" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div>
# </div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>
#             Síguenos</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Descubre</h4>
# <ul>
# <li><a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/sitemap">
#                             Mapa del sitio</a></li>
# <li><a href="/es/bookmarks">
#                             Marcapáginas</a></li>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                     Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>¿En qué podemos ayudarte?</h4>
# <ul>
# <li>
# <a href="/es/help" rel="nofollow">
#                                 Ayuda</a>
# </li>
# <li>
# <a href="/es/contactus">
#                                 Contáctanos</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 ¿Dónde está mi pedido? </a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Envíos internacionales</a>
# </li>
# <li>
# <a href="/es/cancelorder" rel="nofollow">
#                                 Cancelar mi pedido</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                 Devolver mi pedido</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Trabaja con nosotros</h4>
# <ul>
# <li><a href="/es/affiliate">
#                             Afiliados</a></li>
# <li><a href="/es/jobs">
#                             Trabajar en Book Depository</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Información importante</h4>
# <ul>
# <li>
# <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Quejas</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Política de privacidad</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Términos y Condiciones </a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                     Iniciar sesión/Crear cuenta</a></li>
# <li><a href="/es/track">
#                             Mis pedidos</a></li>
# <li><a href="/es/contactus">
#                             Contáctanos</a></li>
# <li><a href="/es/help">
#                             Ayuda</a></li>
# <li><a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Términos y Condiciones </a></li>
# <li><a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Política de privacidad</a></li>
# <li><a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>Aceptamos los siguientes métodos de pago </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-2', requestTime='0.03 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='2.138.111.2', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Oct 11 09:05:28 UTC 2022, cacheEnabled=true}}">
#                         © 2022
#                         The Book Depository Ltd.UK<br/>Número de registro de la empresa: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Comprar","bd_js_too_long_for_shipping_label":"Eso es demasiado largo para nuestras etiquetas de envío","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Eso es demasiado largo","bd_js_could_not_find_address_try_again":"No pudimos encontrar la dirección. Inténtalo de nuevo","bd_saving_percent_off":"Ahorra&lt;br&gt;{0}%","bd_js_total_basket_count":"{0, plural, one {Tienes &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;producto&lt;/span&gt;&lt;/b&gt; en el carrito} other {Tienes &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;productos&lt;/span&gt;&lt;/b&gt; en el carrito}}","bd_js_total_cost":"Costo total: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"mostrar menos","bd_js_item_added_to_your_basket":"Se agregó el producto en el carrito","bd_rrp":"PVPR","bd_link_prefix":"/es","bd_js_unable_get_address_enter_manually":"No podemos obtener la dirección. Ingrésala manualmente:","bd_js_keep_typing_to_refine_search_results":"Sigue escribiendo para ajustar los resultados de búsqueda","bd_js_top_categories":"Categorías principales","bd_price_save":"Ahorra {0}","bd_js_name_only_letters":"El nombre completo solo puede contener letras","bd_js_show_more":"mostrar más","bd_js_enter_valid_email_address":"Ingresa una dirección de correo electrónico válida","bd_js_enter_address_manually":"Ingresar la dirección manualmente","bd_js_more_categories":"Más categorías","bd_30_day_low_price_carousel":"Más bajo","bd_js_continue_shopping":"Seguir comprando","bd_js_account_and_help":"Cuenta y ayuda","bd_js_basket_checkout":"Carrito/proceder al pago","bd_add_to_basket":"Añadir a la cesta","bd_js_enter_first_last_name":"Ingresa un nombre y apellido","bd_js_please_enter_your":"Ingresa tu"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# ![image](img\html-content-web-scraping.png)

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# ![image](img\attribute-example-for-web-scraping-1536x386.png)

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>

# %%
soup.h1
# Out:
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>

# %% [markdown]
# Eliminamos las etiquetas

# %%
soup.h1.get_text()
# Out:
# 'Los más vendidos — nuestros artículos más populares, actualizados diariamente.'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
soup.a['href']
# Out:
# '/help/topic/HelpId/53/How-we-use-cookies#helpContent'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.h1)
print("")
print("Utilizando método .find()")
print(soup.find("h1"))
# Out:
# Sin utilizar método .find()
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>
#
# Utilizando método .find()
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>aquí</a>,
#  <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                  Sí</a>,
#  <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                  Administrar cookies</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                  Cancelar</a>,
#  <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                  Guardar configuración</a>,
#  <a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a>,
#  <a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a>,
#  <a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>,
#  <a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>,
#  <a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a>,
#  <a class="brand-link" href="/es/">
#  <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/logo.svg"/>
#  </a>,
#  <a class="mobile-basket-btn basket-wrap" href="/es/basket">
#  <span class="item-count" data-item-count="0">0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>,
#  <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>,
#  <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>,
#  <a>Menú principal</a>,
#  <a href="/es/category/2/Art-Photography">
#                                          Art &amp; Photography</a>,
#  <a href="/es/category/3389/Audio-Books">
#                                          Audio Books</a>,
#  <a href="/es/category/213/Biography">
#                                          Biography</a>,
#  <a href="/es/category/928/Business-Finance-Law">
#                                          Business, Finance &amp; Law</a>,
#  <a href="/es/category/2455/Childrens-Books">
#                                          Children's Books</a>,
#  <a href="/es/category/1897/Computing">
#                                          Computing</a>,
#  <a href="/es/category/2942/Crafts-Hobbies">
#                                          Crafts &amp; Hobbies</a>,
#  <a href="/es/category/2616/Crime-Thriller">
#                                          Crime &amp; Thriller</a>,
#  <a href="/es/category/240/Dictionaries-Languages">
#                                          Dictionaries &amp; Languages</a>,
#  <a href="/es/category/3245/Entertainment">
#                                          Entertainment</a>,
#  <a href="/es/category/333/Fiction">
#                                          Fiction</a>,
#  <a href="/es/category/2858/Food-Drink">
#                                          Food &amp; Drink</a>,
#  <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                          Graphic Novels, Anime &amp; Manga</a>,
#  <a href="/es/category/2770/Health">
#                                          Health</a>,
#  <a href="/es/category/2638/History-Archaeology">
#                                          History &amp; Archaeology</a>,
#  <a href="/es/category/2892/Home-Garden">
#                                          Home &amp; Garden</a>,
#  <a href="/es/category/2978/Humour">
#                                          Humour</a>,
#  <a href="/es/category/1279/Medical">
#                                          Medical</a>,
#  <a href="/es/category/2819/Mind-Body-Spirit">
#                                          Mind, Body &amp; Spirit</a>,
#  <a href="/es/category/2985/Natural-History">
#                                          Natural History</a>,
#  <a href="/es/category/2802/Personal-Development">
#                                          Personal Development</a>,
#  <a href="/es/category/283/Poetry-Drama">
#                                          Poetry &amp; Drama</a>,
#  <a href="/es/category/375/Reference">
#                                          Reference</a>,
#  <a href="/es/category/3120/Religion">
#                                          Religion</a>,
#  <a href="/es/category/2630/Romance">
#                                          Romance</a>,
#  <a href="/es/category/1476/Science-Geography">
#                                          Science &amp; Geography</a>,
#  <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                          Science Fiction, Fantasy &amp; Horror</a>,
#  <a href="/es/category/632/Society-Social-Sciences">
#                                          Society &amp; Social Sciences</a>,
#  <a href="/es/category/3013/Sport">
#                                          Sport</a>,
#  <a href="/es/category/3385/Stationery">
#                                          Stationery</a>,
#  <a href="/es/category/3328/Teaching-Resources-Education">
#                                          Teaching Resources &amp; Education</a>,
#  <a href="/es/category/1708/Technology-Engineering">
#                                          Technology &amp; Engineering</a>,
#  <a href="/es/category/3391/Teen-Young-Adult">
#                                          Teen &amp; Young Adult</a>,
#  <a href="/es/category/2967/Transport">
#                                          Transport</a>,
#  <a href="/es/category/3098/Travel-Holiday-Guides">
#                                          Travel &amp; Holiday Guides</a>,
#  <a href="/es/category/3392/Books-for-Ages-0-2">
#                                  Ages 0-2</a>,
#  <a href="/es/category/3393/Books-for-Ages-3-5">
#                                  Ages 3-5</a>,
#  <a href="/es/category/3394/Books-for-Ages-6-8">
#                                  Ages 6-8</a>,
#  <a href="/es/category/3395/Books-for-Ages-9-11">
#                                  Ages 9-11</a>,
#  <a href="/es/category/3391/Teen-Young-Adult">
#                                  Teen &amp; Young Adult</a>,
#  <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
#  <div class="link-text">J. K. Rowling</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/roald-dahl">
#  <div class="link-text">Roald Dahl</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/julia-donaldson">
#  <div class="link-text">Julia Donaldson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/stephen-king">
#  <div class="link-text">Stephen King</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/david-walliams">
#  <div class="link-text">David Walliams</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
#  <div class="link-text">Dr. Seuss</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/andy-griffiths">
#  <div class="link-text">Andy Griffiths</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
#  <div class="link-text">James Patterson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
#  <div class="link-text">Sarah J. Maas</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/enid-blyton">
#  <div class="link-text">Enid Blyton</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/john-green">
#  <div class="link-text">John Green</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
#  <div class="link-text">Brandon Sanderson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/popular-authors">
#  <div class="link-text">See all</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/harry-potter">
#  <div class="link-text">Harry Potter</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/game-of-thrones">
#  <div class="link-text">Game Of Thrones</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/lego">
#  <div class="link-text">Lego</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
#  <div class="link-text">Divergent</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
#  <div class="link-text">Throne Of Glass</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/star-wars">
#  <div class="link-text">Star Wars</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/spanish">
#  <div class="link-text">Books in Spanish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/polish-books">
#  <div class="link-text">Books in Polish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/german-books">
#  <div class="link-text">Books in German</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/french-books">
#  <div class="link-text">Books in French</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/languages">
#  <div class="link-text">Languages Bookshop</div>
#  </a>,
#  <a href="/es/bestsellers">Los más vendidos</a>,
#  <a href="/es/comingsoon">Próximamente </a>,
#  <a href="/es/top-new-releases">Nuevos lanzamientos</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">
#          Español</a>,
#  <a class="global-nav-close" href="#"><i class="icon-close"></i></a>,
#  <a class="language-option" data-value="en_US" href="#">
#                              Inglés (English)</a>,
#  <a class="language-option" data-value="es_ES" href="#">
#                              Español</a>,
#  <a class="basket-btn" href="/es/basket" rel="nofollow">
#  <span class="item-count">
#                          0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filtrar tu búsqueda">Filtrar tu búsqueda</a>,
#  <a>1</a>,
#  <a href="/es/bestsellers?page=2">2</a>,
#  <a href="/es/bestsellers?page=3">3</a>,
#  <a href="/es/bestsellers?page=4">4</a>,
#  <a href="/es/bestsellers?page=5">5</a>,
#  <a href="/es/bestsellers?page=2">»</a>,
#  <a href="/es/TommyInnit-Says-Quote-Book-Tom-Simons/9781529427974" itemprop="url">
#  <img alt="TommyInnit Says...The Quote Book" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5294/9781529427974.jpg"/>
#  </a>,
#  <a href="/es/TommyInnit-Says-Quote-Book-Tom-Simons/9781529427974">
#                      TommyInnit Says...The Quote Book<br/>
#  </a>,
#  <a href="/es/author/Tom-Simons" itemprop="author">Tom Simons</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529427974" data-price="19.39" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529427974" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Courtiers-Valentine-Low/9781472290908" itemprop="url">
#  <img alt="Courtiers" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4722/9781472290908.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>7%</div>
#  </a>,
#  <a href="/es/Courtiers-Valentine-Low/9781472290908">
#                      Courtiers<br/>
#  </a>,
#  <a href="/es/author/Valentine-Low" itemprop="author">Valentine Low</a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472290908" data-price="23.03" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781472290908" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Verity-Colleen-Hoover/9781408726600" itemprop="url">
#  <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
#  </a>,
#  <a href="/es/Verity-Colleen-Hoover/9781408726600">
#                      Verity<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Verity" href="/es/Verity-Colleen-Hoover/9781408726600">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="13.64" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179" itemprop="url">
#  <img alt="It Starts with Us" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398518179.jpg"/>
#  </a>,
#  <a href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179">
#                      It Starts with Us<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for It Starts with Us" href="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398518179" data-price="19.14" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398518179" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824" itemprop="url">
#  <img alt="I'm Glad My Mom Died" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9821/9781982185824.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>17%</div>
#  </a>,
#  <a href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
#                      I'm Glad My Mom Died<br/>
#  </a>,
#  <a href="/es/author/Jennette-McCurdy" itemprop="author">Jennette McCurdy</a>,
#  <a aria-label="Ratings for I'm Glad My Mom Died" href="/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781982185824" data-price="23.4" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781982185824" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
#  <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
#  </a>,
#  <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                      It Ends With Us: The most heartbreaking novel you'll ever read<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="13.64" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Loss-Donna-Ashworth/9781785304422" itemprop="url">
#  <img alt="Loss" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7853/9781785304422.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>33%</div>
#  </a>,
#  <a href="/es/Loss-Donna-Ashworth/9781785304422">
#                      Loss<br/>
#  </a>,
#  <a href="/es/author/Donna-Ashworth" itemprop="author">Donna Ashworth</a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785304422" data-price="12.68" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785304422" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Life-Donna-Ashworth/9781785304446" itemprop="url">
#  <img alt="Life" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7853/9781785304446.jpg"/>
#  </a>,
#  <a href="/es/Life-Donna-Ashworth/9781785304446">
#                      Life<br/>
#  </a>,
#  <a href="/es/author/Donna-Ashworth" itemprop="author">Donna Ashworth</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785304446" data-price="12.68" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785304446" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
#  <img alt="Atomic Habits" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
#  </a>,
#  <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                      Atomic Habits<br/>
#  </a>,
#  <a href="/es/author/James-Clear" itemprop="author">James Clear</a>,
#  <a aria-label="Ratings for Atomic Habits" href="/es/Atomic-Habits-James-Clear/9781847941831">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781847941831" data-price="20.75" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
#  <img alt="Seven Husbands of Evelyn Hugo" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
#  </a>,
#  <a href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                      Seven Husbands of Evelyn Hugo<br/>
#  </a>,
#  <a href="/es/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>,
#  <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515697" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Invisible-Life-Addie-LaRue-Illustrated-edition-V-E-Schwab/9781803364186" itemprop="url">
#  <img alt="The Invisible Life of Addie LaRue - Illustrated edition" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8033/9781803364186.jpg"/>
#  </a>,
#  <a href="/es/Invisible-Life-Addie-LaRue-Illustrated-edition-V-E-Schwab/9781803364186">
#                      The Invisible Life of Addie LaRue - Illustrated edition<br/>
#  </a>,
#  <a href="/es/author/V-E-Schwab" itemprop="author">V.E. Schwab</a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781803364186" data-price="22.84" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781803364186" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Love-Donna-Ashworth/9781785304408" itemprop="url">
#  <img alt="Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7853/9781785304408.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>33%</div>
#  </a>,
#  <a href="/es/Love-Donna-Ashworth/9781785304408">
#                      Love<br/>
#  </a>,
#  <a href="/es/author/Donna-Ashworth" itemprop="author">Donna Ashworth</a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785304408" data-price="12.68" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785304408" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Ugly-Love-Colleen-Hoover/9781471136726" itemprop="url">
#  <img alt="Ugly Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471136726.jpg"/>
#  </a>,
#  <a href="/es/Ugly-Love-Colleen-Hoover/9781471136726">
#                      Ugly Love<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Ugly Love" href="/es/Ugly-Love-Colleen-Hoover/9781471136726">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471136726" data-price="12.83" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471136726" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Secret-History-Donna-Tartt/9780140167771" itemprop="url">
#  <img alt="The Secret History" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1401/9780140167771.jpg"/>
#  </a>,
#  <a href="/es/Secret-History-Donna-Tartt/9780140167771">
#                      The Secret History<br/>
#  </a>,
#  <a href="/es/author/Donna-Tartt" itemprop="author">Donna Tartt</a>,
#  <a aria-label="Ratings for The Secret History" href="/es/Secret-History-Donna-Tartt/9780140167771">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780140167771" data-price="14.99" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780140167771" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581" itemprop="url">
#  <img alt="Before the Coffee Gets Cold" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5290/9781529029581.jpg"/>
#  </a>,
#  <a href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#                      Before the Coffee Gets Cold<br/>
#  </a>,
#  <a href="/es/author/Toshikazu-Kawaguchi" itemprop="author">Toshikazu Kawaguchi</a>,
#  <a aria-label="Ratings for Before the Coffee Gets Cold" href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529029581" data-price="13.8" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529029581" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Where-Crawdads-Sing-Delia-Owens/9781472154668" itemprop="url">
#  <img alt="Where the Crawdads Sing" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4721/9781472154668.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>6%</div>
#  </a>,
#  <a href="/es/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#                      Where the Crawdads Sing<br/>
#  </a>,
#  <a href="/es/author/Delia-Owens" itemprop="author">Delia Owens</a>,
#  <a aria-label="Ratings for Where the Crawdads Sing" href="/es/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472154668" data-price="12.6" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781472154668" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Twisted-Love-Ana-Huang/9780349434278" itemprop="url">
#  <img alt="Twisted Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349434278.jpg"/>
#  </a>,
#  <a href="/es/Twisted-Love-Ana-Huang/9780349434278">
#                      Twisted Love<br/>
#  </a>,
#  <a href="/es/author/Ana-Huang" itemprop="author">Ana Huang</a>,
#  <a aria-label="Ratings for Twisted Love" href="/es/Twisted-Love-Ana-Huang/9780349434278">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349434278" data-price="12.21" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349434278" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Always-Room-for-Christmas-Pud-Aunty-Donna/9780143779810" itemprop="url">
#  <img alt="Always Room for Christmas Pud" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1437/9780143779810.jpg"/>
#  </a>,
#  <a href="/es/Always-Room-for-Christmas-Pud-Aunty-Donna/9780143779810">
#                      Always Room for Christmas Pud<br/>
#  </a>,
#  <a href="/es/author/Aunty-Donna" itemprop="author">Aunty Donna</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780143779810" data-price="17.08" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780143779810" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Twisted-Lies-Ana-Huang/9780349434285" itemprop="url">
#  <img alt="Twisted Lies" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349434285.jpg"/>
#  </a>,
#  <a href="/es/Twisted-Lies-Ana-Huang/9780349434285">
#                      Twisted Lies<br/>
#  </a>,
#  <a href="/es/author/Ana-Huang" itemprop="author">Ana Huang</a>,
#  <a aria-label="Ratings for Twisted Lies" href="/es/Twisted-Lies-Ana-Huang/9780349434285">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349434285" data-price="12.84" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349434285" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Rooms-Wonder-Johanna-Basford/9781529148305" itemprop="url">
#  <img alt="Rooms of Wonder" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5291/9781529148305.jpg"/>
#  </a>,
#  <a href="/es/Rooms-Wonder-Johanna-Basford/9781529148305">
#                      Rooms of Wonder<br/>
#  </a>,
#  <a href="/es/author/Johanna-Basford" itemprop="author">Johanna Basford</a>,
#  <a aria-label="Ratings for Rooms of Wonder" href="/es/Rooms-Wonder-Johanna-Basford/9781529148305">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529148305" data-price="19.82" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529148305" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/It-Ends-With-Us-Colleen-Hoover/9781398520783" itemprop="url">
#  <img alt="It Ends With Us" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398520783.jpg"/>
#  </a>,
#  <a href="/es/It-Ends-With-Us-Colleen-Hoover/9781398520783">
#                      It Ends With Us<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398520783" data-price="18.75" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398520783" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/If-We-Were-Villains-M-L-Rio/9781785656477" itemprop="url">
#  <img alt="If We Were Villains" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7856/9781785656477.jpg"/>
#  </a>,
#  <a href="/es/If-We-Were-Villains-M-L-Rio/9781785656477">
#                      If We Were Villains<br/>
#  </a>,
#  <a href="/es/author/M-L-Rio" itemprop="author">M. L. Rio</a>,
#  <a aria-label="Ratings for If We Were Villains" href="/es/If-We-Were-Villains-M-L-Rio/9781785656477">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781785656477" data-price="14.41" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785656477" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/12-Rules-for-Life-Jordan-B-Peterson/9780141988511" itemprop="url">
#  <img alt="12 Rules for Life" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141988511.jpg"/>
#  </a>,
#  <a href="/es/12-Rules-for-Life-Jordan-B-Peterson/9780141988511">
#                      12 Rules for Life<br/>
#  </a>,
#  <a href="/es/author/Jordan-B-Peterson" itemprop="author">Jordan B. Peterson</a>,
#  <a aria-label="Ratings for 12 Rules for Life" href="/es/12-Rules-for-Life-Jordan-B-Peterson/9780141988511">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141988511" data-price="15.14" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780141988511" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Woks-Life-Bill-Leung/9780593233894" itemprop="url">
#  <img alt="The Woks of Life" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5932/9780593233894.jpg"/>
#  </a>,
#  <a href="/es/Woks-Life-Bill-Leung/9780593233894">
#                      The Woks of Life<br/>
#  </a>,
#  <a href="/es/author/Bill-Leung" itemprop="author">Bill Leung</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780593233894" data-price="39.0" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780593233894" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Saga-10-Brian-K-Vaughan/9781534323346" itemprop="url">
#  <img alt="Saga, Volume 10" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5343/9781534323346.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>8%</div>
#  </a>,
#  <a href="/es/Saga-10-Brian-K-Vaughan/9781534323346">
#                      Saga, Volume 10<br/>
#  </a>,
#  <a href="/es/author/Brian-K-Vaughan" itemprop="author">Brian K Vaughan</a>,
#  <a aria-label="Ratings for Saga, Volume 10" href="/es/Saga-10-Brian-K-Vaughan/9781534323346">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781534323346" data-price="17.48" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781534323346" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611" itemprop="url">
#  <img alt="The Body Keeps the Score" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141978611.jpg"/>
#  </a>,
#  <a href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#                      The Body Keeps the Score<br/>
#  </a>,
#  <a href="/es/author/Bessel-van-der-Kolk" itemprop="author">Bessel van der Kolk</a>,
#  <a aria-label="Ratings for The Body Keeps the Score" href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141978611" data-price="17.15" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780141978611" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740" itemprop="url">
#  <img alt="Things We Never Got Over" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399713740.jpg"/>
#  </a>,
#  <a href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740">
#                      Things We Never Got Over<br/>
#  </a>,
#  <a href="/es/author/Lucy-Score" itemprop="author">Lucy Score</a>,
#  <a aria-label="Ratings for Things We Never Got Over" href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781399713740" data-price="12.59" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399713740" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/November-9-Colleen-Hoover/9781471154621" itemprop="url">
#  <img alt="November 9" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471154621.jpg"/>
#  </a>,
#  <a href="/es/November-9-Colleen-Hoover/9781471154621">
#                      November 9<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for November 9" href="/es/November-9-Colleen-Hoover/9781471154621">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471154621" data-price="13.29" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471154621" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036" itemprop="url">
#  <img alt="Red, White &amp; Royal Blue: Collector's Edition" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/2508/9781250856036.jpg"/>
#  </a>,
#  <a href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036">
#                      Red, White &amp; Royal Blue: Collector's Edition<br/>
#  </a>,
#  <a href="/es/author/Casey-McQuiston" itemprop="author">Casey McQuiston</a>,
#  <a aria-label="Ratings for Red, White &amp; Royal Blue: Collector's Edition" href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary" href="/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036" rel="nofollow">
#                            Notificarme</a>,
#  <a href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268" itemprop="url">
#  <img alt="The Thursday Murder Club" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2419/9780241988268.jpg"/>
#  </a>,
#  <a href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268">
#                      The Thursday Murder Club<br/>
#  </a>,
#  <a href="/es/author/Richard-Osman" itemprop="author">Richard Osman</a>,
#  <a aria-label="Ratings for The Thursday Murder Club" href="/es/Thursday-Murder-Club-Richard-Osman/9780241988268">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241988268" data-price="13.74" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780241988268" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a>1</a>,
#  <a href="/es/bestsellers?page=2">2</a>,
#  <a href="/es/bestsellers?page=3">3</a>,
#  <a href="/es/bestsellers?page=4">4</a>,
#  <a href="/es/bestsellers?page=5">5</a>,
#  <a href="/es/bestsellers?page=2">»</a>,
#  <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-fb"></i>
#  </a>,
#  <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-tw"></i>
#  </a>,
#  <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-pi"></i>
#  </a>,
#  <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-in"></i>
#  </a>,
#  <a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                              Conócenos</a>,
#  <a href="/es/sitemap">
#                              Mapa del sitio</a>,
#  <a href="/es/bookmarks">
#                              Marcapáginas</a>,
#  <a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                      Iniciar sesión/Crear cuenta</a>,
#  <a href="/es/help" rel="nofollow">
#                                  Ayuda</a>,
#  <a href="/es/contactus">
#                                  Contáctanos</a>,
#  <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                  ¿Dónde está mi pedido? </a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                  Envíos internacionales</a>,
#  <a href="/es/cancelorder" rel="nofollow">
#                                  Cancelar mi pedido</a>,
#  <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                  Devolver mi pedido</a>,
#  <a href="/es/affiliate">
#                              Afiliados</a>,
#  <a href="/es/jobs">
#                              Trabajar en Book Depository</a>,
#  <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                  Quejas</a>,
#  <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                  Cookies</a>,
#  <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                  Política de privacidad</a>,
#  <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                  Términos y Condiciones </a>,
#  <a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                      Iniciar sesión/Crear cuenta</a>,
#  <a href="/es/track">
#                              Mis pedidos</a>,
#  <a href="/es/contactus">
#                              Contáctanos</a>,
#  <a href="/es/help">
#                              Ayuda</a>,
#  <a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                              Conócenos</a>,
#  <a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                              Términos y Condiciones </a>,
#  <a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                              Política de privacidad</a>,
#  <a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                              Cookies</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
# Out:
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>aquí</a>
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Sí</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</a>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>
# <a class="showLess" role="button">Mostrar menos</a>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 30 libros con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - book titles
# - formats (paperback or hardback)
# - publication dates
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los titulos de los libros (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un libro y elegimos inspeccionar)

# %%
all_h3 = soup.find_all("h3", class_="title")
for h3 in all_h3:
       print(h3.get_text(strip=True))
# Out:
# TommyInnit Says...The Quote Book
# Courtiers
# Verity
# It Starts with Us
# I'm Glad My Mom Died
# It Ends With Us: The most heartbreaking novel you'll ever read
# Loss
# Life
# Atomic Habits
# Seven Husbands of Evelyn Hugo
# The Invisible Life of Addie LaRue - Illustrated edition
# Love
# Ugly Love
# The Secret History
# Before the Coffee Gets Cold
# Where the Crawdads Sing
# Twisted Love
# Always Room for Christmas Pud
# Twisted Lies
# Rooms of Wonder
# It Ends With Us
# If We Were Villains
# 12 Rules for Life
# The Woks of Life
# Saga, Volume 10
# The Body Keeps the Score
# Things We Never Got Over
# November 9
# Red, White & Royal Blue: Collector's Edition
# The Thursday Murder Club

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en **class__=”title”** no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los formatos de los libros

# %% [markdown]
# Del paso anterior tenemos todos los títulos de libros de la página de los más vendidos. Pero, ¿qué sabemos acerca de sus formatos? ¿Hay más libros de tapa dura o tapa blanda?
#
# Averigüémoslo inspeccionando el elemento de formato de libro:

# %% [markdown]
# Como siempre inspeccionamos y buscamos el formato..

# %% [markdown]
# Y como queremos saber la cantidad de cada formato lo metemos en dataframe

# %%
all_formats = soup.find_all("p", class_="format")
for format in all_formats:
       print(format.get_text(strip=True))
# Out:
# Hardback
# Hardback
# Paperback
# Paperback
# Hardback
# Paperback
# Hardback
# Hardback
# Paperback
# Paperback
# Hardback
# Hardback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Hardback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Hardback
# Paperback
# Paperback
# Paperback
# Paperback
# Hardback
# Paperback

# %%
formats = soup.select("div.item-info p.format") # div y p son etiquetas donde se encuentran
formats_series = pd.Series(formats)
formats_series.value_counts()
# Out:
# [Paperback]    20
# [Hardback]     10
# dtype: int64

# %% [markdown]
# ## Obtener las fechas de publicación (find_all + get_text)

# %% [markdown]
# Al igual que antes inspeccionamos....

# %%
dates = soup.find_all("p", class_="published")
dates = [date.get_text()for date in dates] #con esta list comprehension obtenemos solo el año
dates_series = pd.Series(dates)
dates_series.value_counts()
# Out:
# 18 Oct 2022    3
# 04 Oct 2022    3
# 06 Oct 2022    2
# 13 Oct 2022    1
# 05 May 2022    1
# 11 Oct 2022    1
# 11 Nov 2015    1
# 14 Jul 2022    1
# 24 Sep 2015    1
# 05 Oct 2022    1
# 01 Nov 2022    1
# 07 May 2019    1
# 13 Jun 2017    1
# 01 Aug 2022    1
# 19 Sep 2019    1
# 20 Dec 2019    1
# 01 Jul 1995    1
# 21 Jan 2016    1
# 01 Oct 2022    1
# 14 Oct 2021    1
# 27 Nov 2018    1
# 02 Aug 2016    1
# 15 Sep 2022    1
# 20 Jan 2022    1
# 13 May 2021    1
# dtype: int64

# %%
dates = soup.find_all("p", class_="published")
dates = [date.get_text()[-4:] for date in dates] #con esta list comprehension obtenemos solo el año
dates_series = pd.Series(dates)
dates_series.value_counts()
# Out:
# 2022    18
# 2019     3
# 2016     2
# 2021     2
# 2015     2
# 2018     1
# 1995     1
# 2017     1
# dtype: int64

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %% [markdown]
# Inspeccionamos..

# %%
prices = soup.find_all("p", class_="price")

# %%
prices = soup.find_all("span", class_="sale-price")
prices
# Out:
# [<span class="sale-price">19,39 €</span>,
#  <span class="sale-price">23,03 €</span>,
#  <span class="sale-price">13,64 €</span>,
#  <span class="sale-price">19,14 €</span>,
#  <span class="sale-price">23,40 €</span>,
#  <span class="sale-price">13,64 €</span>,
#  <span class="sale-price">12,68 €</span>,
#  <span class="sale-price">12,68 €</span>,
#  <span class="sale-price">20,75 €</span>,
#  <span class="sale-price">12,58 €</span>,
#  <span class="sale-price">22,84 €</span>,
#  <span class="sale-price">12,68 €</span>,
#  <span class="sale-price">12,83 €</span>,
#  <span class="sale-price">14,99 €</span>,
#  <span class="sale-price">13,80 €</span>,
#  <span class="sale-price">12,60 €</span>,
#  <span class="sale-price">12,21 €</span>,
#  <span class="sale-price">17,08 €</span>,
#  <span class="sale-price">12,84 €</span>,
#  <span class="sale-price">19,82 €</span>,
#  <span class="sale-price">18,75 €</span>,
#  <span class="sale-price">14,41 €</span>,
#  <span class="sale-price">15,14 €</span>,
#  <span class="sale-price">39,00 €</span>,
#  <span class="sale-price">17,48 €</span>,
#  <span class="sale-price">17,15 €</span>,
#  <span class="sale-price">12,59 €</span>,
#  <span class="sale-price">13,29 €</span>,
#  <span class="sale-price">13,74 €</span>]

# %%
print(prices)
# Out:
# [<p class="price">
# <span class="sale-price">19,39 €</span>
# </p>, <p class="price">
# <span class="sale-price">23,03 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">25,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">13,64 €</span>
# </p>, <p class="price">
# <span class="sale-price">19,14 €</span>
# </p>, <p class="price">
# <span class="sale-price">23,40 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">28,50 €</span>
# </p>, <p class="price">
# <span class="sale-price">13,64 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,68 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">19,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,68 €</span>
# </p>, <p class="price">
# <span class="sale-price">20,75 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">21,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,58 €</span>
# </p>, <p class="price">
# <span class="sale-price">22,84 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">23,50 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,68 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">19,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,83 €</span>
# </p>, <p class="price">
# <span class="sale-price">14,99 €</span>
# </p>, <p class="price">
# <span class="sale-price">13,80 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,60 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">13,50 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,21 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">12,50 €</span>
# </p>, <p class="price">
# <span class="sale-price">17,08 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,84 €</span>
# </p>, <p class="price">
# <span class="sale-price">19,82 €</span>
# </p>, <p class="price">
# <span class="sale-price">18,75 €</span>
# </p>, <p class="price">
# <span class="sale-price">14,41 €</span>
# </p>, <p class="price">
# <span class="sale-price">15,14 €</span>
# </p>, <p class="price">
# <span class="sale-price">39,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">17,48 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">19,00 €</span>
# </p>, <p class="price">
# <span class="sale-price">17,15 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">17,50 €</span>
# </p>, <p class="price">
# <span class="sale-price">12,59 €</span>
# </p>, <p class="price">
# <span class="sale-price">13,29 €</span>
# </p>, <p class="price">
# <span class="sale-price">13,74 €</span>
# </p>]

# %%
prices[0]
# Out:
# <p class="price">
# <span class="sale-price">19,39 €</span>
# </p>

# %%
prices[5].get_text(strip=True).split(' ')
# Out:
# ['13,64', '€']

# %%
# final_prices = []
# for price in prices:
#       original_price = price.find("span", class_="rrp")
#       if original_price:
#              current_price = str(original_price.previousSibling).strip() # nos quedamos solo con el numero sin etiquetas
#              current_price = float(current_price.split("€")[0].replace(",", ".")) # quitamos el signo de euro y reemplazamos la coma por el punto para que python lo reconozca con float
#              final_prices.append(current_price)
#       else:
#              current_price = float(price.get_text(strip=True).split("€")[0].replace(",", "."))
#              final_prices.append(current_price)

# %%
final_prices = []
for price in prices:
    original_price = price.find("span", class_="sale-price")
    original_price = original_price.get_text()
    original_price = float(original_price.split("€")[0].replace(",", "."))
    final_prices.append(original_price)

# %%
final_price_compress = [float(price.find("span", class_="sale-price").get_text().split(" €")[0].replace(",", ".")) for price in prices]

# %%
print(final_prices==final_price_compress)
# Out:
# True

# %% [markdown]
# ## Recolectar información de un libro

# %% [markdown]
# Primero creamos un soup en la pagína 'principal'

# %%
libros = soup.find_all(class_='item-img')

# %% [markdown]
# Guardamos en una variable la url principal

# %%
url_principal = 'https://www.bookdepository.com'

# %% [markdown]
# Creamos una lista con los urls de los libros

# %%
lista_URLs = []
for libro in libros:
    URL_libro = libro.find('a')['href']
    lista_URLs.append(url_principal+URL_libro)

lista_URLs
# Out:
# ['https://www.bookdepository.com/es/TommyInnit-Says-Quote-Book-Tom-Simons/9781529427974',
#  'https://www.bookdepository.com/es/Courtiers-Valentine-Low/9781472290908',
#  'https://www.bookdepository.com/es/Verity-Colleen-Hoover/9781408726600',
#  'https://www.bookdepository.com/es/It-Starts-with-Us-Colleen-Hoover/9781398518179',
#  'https://www.bookdepository.com/es/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824',
#  'https://www.bookdepository.com/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267',
#  'https://www.bookdepository.com/es/Loss-Donna-Ashworth/9781785304422',
#  'https://www.bookdepository.com/es/Life-Donna-Ashworth/9781785304446',
#  'https://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831',
#  'https://www.bookdepository.com/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697',
#  'https://www.bookdepository.com/es/Invisible-Life-Addie-LaRue-Illustrated-edition-V-E-Schwab/9781803364186',
#  'https://www.bookdepository.com/es/Love-Donna-Ashworth/9781785304408',
#  'https://www.bookdepository.com/es/Ugly-Love-Colleen-Hoover/9781471136726',
#  'https://www.bookdepository.com/es/Secret-History-Donna-Tartt/9780140167771',
#  'https://www.bookdepository.com/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581',
#  'https://www.bookdepository.com/es/Where-Crawdads-Sing-Delia-Owens/9781472154668',
#  'https://www.bookdepository.com/es/Twisted-Love-Ana-Huang/9780349434278',
#  'https://www.bookdepository.com/es/Always-Room-for-Christmas-Pud-Aunty-Donna/9780143779810',
#  'https://www.bookdepository.com/es/Twisted-Lies-Ana-Huang/9780349434285',
#  'https://www.bookdepository.com/es/Rooms-Wonder-Johanna-Basford/9781529148305',
#  'https://www.bookdepository.com/es/It-Ends-With-Us-Colleen-Hoover/9781398520783',
#  'https://www.bookdepository.com/es/If-We-Were-Villains-M-L-Rio/9781785656477',
#  'https://www.bookdepository.com/es/12-Rules-for-Life-Jordan-B-Peterson/9780141988511',
#  'https://www.bookdepository.com/es/Woks-Life-Bill-Leung/9780593233894',
#  'https://www.bookdepository.com/es/Saga-10-Brian-K-Vaughan/9781534323346',
#  'https://www.bookdepository.com/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611',
#  'https://www.bookdepository.com/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740',
#  'https://www.bookdepository.com/es/November-9-Colleen-Hoover/9781471154621',
#  'https://www.bookdepository.com/es/Red-White-Royal-Blue-Collectors-Edition-Casey-McQuiston/9781250856036',
#  'https://www.bookdepository.com/es/Thursday-Murder-Club-Richard-Osman/9780241988268']

# %% [markdown]
# Vamos a analizar el url de un libro primero

# %%
# Hacemos un nuevo request para el primer libro: 
r = requests.get(lista_URLs[3])

# Creamos una sopa específica con la info de cada libro
soup_libro = bs(r.text, "lxml")

# %% [markdown]
# creamos un soup del primer libro

# %%
soup_libro
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="Book Depository is the world's most international online bookstore offering over  million books with free delivery worldwide. " name="description"/>
# <meta content="books,free,delivery,worldwide,book,offers,bestsellers,coming soon" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <title>
# 	Envío gratis en todo el mundo en todos tus libros de Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="">
# <div class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>Usamos cookies para mejorar este sitio</h2>
# <p>Las cookies se usan para brindar, analizar y mejorar nuestros servicios, proporcionar herramientas de chat y mostrarte<br/>contenido publicitario relevante. Puedes obtener más información acerca de nuestro uso de cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>aquí</a></p><h2>¿Aceptas las cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Sí</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</a>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Preferencias de cookies</h2>
# <p>Usamos cookies y herramientas similares que son necesarias para facilitarle las compras, incluidas las que usan los terceros autorizados (colectivamente, "cookies"), para los fines que se describen a continuación.
#      <br/>Para obtener más información acerca de cómo usamos las cookies (y cómo las usan los terceros autorizados) y cómo cambiar tu configuración, consulta el <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>. Las elecciones que realices aquí se aplicarán a la interacción con este servicio en este dispositivo.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Indispensable</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>Usamos cookies para brindar nuestros servicios,</span>
# <div>
# <div class="additionalInfo wrapping-space">por ejemplo, para realizar un seguimiento de los artículos almacenados en tu canasta de compras, prevenir actividades fraudulentas, mejorar la seguridad de nuestros servicios, realizar un seguimiento de tus preferencias específicas (como preferencias de moneda o idioma) y mostrar características, productos y servicios que puedan ser de tu interés. Debido a que usamos cookies para brindarte nuestros servicios, estas no se pueden desactivar cuando se usan con este fin.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Desempeño y analítica</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ACTIVADO</span>
# <span class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si usted lo acepta, usaremos cookies para entender cómo los clientes usan nuestros servicios</span>
# <div>
# <div class="additionalInfo wrapping-space"> (como por ejemplo, medir visitas en nuestra página web) y poder mejorarlos. Por ejemplo, usamos cookies para realizar investigaciones y diagnósticos a fin de mejorar el contenido, los productos y los servicios, y para evaluar y analizar el desempeño de nuestros servicios.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Publicidad</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ACTIVADO</span>
# <span class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si usted lo acepta, usaremos cookies para completar su experiencia de compra, tal y como se describe en el <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>,</span>
# <div>
# <div class="additionalInfo wrapping-space"> para ofrecerle ciertos tipos de anuncios relevantes según tus intereses en Book Depository. Esto incluye utilizar las cookies de terceros para mostrarle y medir anuncios (visite el Aviso sobre Publicidad Basada en los intereses del usuario para entender cómo usamos cookies para mostrarle anuncios basados en sus intereses), medir la efectividad de anuncios y, como parte necesaria para los terceros, para prestarle servicios en nombre de Book Depository.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                 Cancelar</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Guardar configuración</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a></li>
# <li class="mob-nav-account"><a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a></li>
# <li class="mob-nav-account"><a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/es/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/es/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/es/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Buscar libros por palabra clave / título / autor / ISBN" class="text-input" name="searchTerm" placeholder="Buscar libros por palabra clave / título / autor / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Buscar</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 Todas las categorías</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Menú principal</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/es/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/es/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/es/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/es/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/es/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Libros infantiles por edades</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/es/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/es/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/es/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/es/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/es/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/es/bestsellers">Los más vendidos</a></li>
# <li class="mob-nav-shop"><a href="/es/comingsoon">Próximamente </a></li>
# <li class="mob-nav-shop"><a href="/es/top-new-releases">Nuevos lanzamientos</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         Español</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Idiomas</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             Inglés (English)</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Español</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="Español">
# <select id="selectLanguage" name="selectLanguage">
# <option value="en_US">
#                     English</option>
# <option selected="selected" value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/es/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div onclick="void(0);">
# <div class="main-content no-borders book-page full-width">
# <ol class="breadcrumb">
# <li class="title">Categorías:</li>
# <li>
# <a href="/es/category/333/Fiction-Books">
#                                             Fiction Books</a>
# </li>
# <li>
# <a href="/es/category/334/Contemporary-Fiction">
#                                             Contemporary Fiction</a>
# </li>
# <li>
# <a href="/es/category/358/Romance">
#                                             Romance</a>
# </li>
# <li>
# <a href="/es/category/2630/Romance-Books">
#                                             Romance Books</a>
# </li>
# <li>
# <a href="/es/category/359/Adult-Contemporary-Romance">
#                                             Adult &amp; Contemporary Romance</a>
# </li>
# <li>
# <a href="/es/category/2631/Adult-Contemporary-Romance">
#                                             Adult &amp; Contemporary Romance</a>
# </li>
# <li>
# <a href="/es/category/644/Poverty-Unemployment">
#                                             Poverty  &amp; Unemployment</a>
# </li>
# <li>
# <a class="active" href="/es/category/2771/Safety-Home">
#                                             Safety In The Home</a>
# </li>
# </ol>
# <div class="item-wrap" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-block">
# <meta content="/es/It-Starts-with-Us-Colleen-Hoover/9781398518179" itemprop="url"/>
# <span itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="http://schema.org/InStock" itemprop="availability"/>
# <meta content="http://schema.org/NewCondition" itemprop="itemCondition"/>
# </span>
# <div class="item-img">
# <i class="icon-mobile-zoom"></i>
# <div class="item-img-content">
# <img alt="It Starts with Us" class="book-img" itemprop="image" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/3985/9781398518179.jpg"/>
# </div>
# <div class="copy-content visible-md" data-target=".social-wrap"></div>
# </div>
# <div class="item-info">
# <h1 itemprop="name">It Starts with Us : the highly anticipated sequel to IT ENDS WITH US</h1>
# <div class="rating-wrap hidden-md" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# </div>
# </a>
# <span itemprop="ratingValue">
#                             4.77</span>
# <span class="rating-count">
#                             (2,157 opiniones de clientes de Goodreads)
# </span>
# <meta content="2157" itemprop="ratingCount"/>
# </div>
# <ul class="meta-info hidden-md">
# <li>Paperback</li>
# <li>
# <span itemprop="inLanguage" itemtype="http://schema.org/Language">
# <a href="/es/search/advanced?searchLang=123">English</a></span>
# </li>
# </ul>
# <div class="author-info hidden-md">
#                             By (author)
#
#                                 <span itemprop="author" itemscope="Colleen Hoover" itemtype="http://schema.org/Person">
# <a href="/es/author/Colleen-Hoover" itemprop="url">
# <span itemprop="name">
#                                     Colleen Hoover</span>
# </a>
# </span>
# </div>
# <ul class="social-wrap hidden-xs hidden-sm hidden-md">
# <li class="label">Compartir</li>
# <li><a href="mailto:?subject=Sharing a book&amp;body=I saw this book at Book Depository and thought you might like it:%0D%0A%0D%0Ahttps://www.bookdepository.com/es/It-Starts-with-Us-Colleen-Hoover/9781398518179" target="_blank"><i class="icon-em"></i></a></li>
# <li><a href="/es/share/book?id=58085844&amp;service=facebook&amp;mess=book" target="_blank"><i class="icon-fb"></i></a></li>
# <li><a href="https://twitter.com/intent/tweet?text=I've+discovered+It+Starts+with+Us&amp;url=https%3a%2f%2fwww.bookdepository.com%2fes%2fIt-Starts-with-Us-Colleen-Hoover%2f9781398518179&amp;via=bookdepository" target="_blank"><i class="icon-tw"></i></a></li>
# <li><a href="http://pinterest.com/pin/create/button/?url=https://www.bookdepository.com/es/It-Starts-with-Us-Colleen-Hoover/9781398518179&amp;media=https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/3985/9781398518179.jpg&amp;description=Before%C2%A0It-Ends-with-Us-it-started-with-Atlas-Colleen-Hoover-tells-fan-favourite-Atlas%E2%80%99s-side-of-the-story-and-shares-what-comes-next-in-this-long-anticipated-sequel-to-the-1-Sunday%C2%A0Times%C2%A0bestseller%C2%A0It-Ends-with-Us-Lily-and-her-ex-husband-Ryle-have-just-settled-into-a-civil-co-parenting-rhythm-when-she-suddenly-bumps-into-her-first-love-Atlas-again-After-nearly-two-years-separated-she-is-elated-that-for-once-time-is-on-their-side-and-she-immediately-says-yes-when-Atlas-asks-her-on-a-date-But-her-excitement-is-quickly-hampered-by-the-knowledge-that-though-they-are-no-longer-married-Ryle-is-still-very-much-a-part-of-her-life%E2%80%94and-Atlas-Corrigan-is-the-one-man-he-will-hate-being-in-his-ex-wife-and-daughter%E2%80%99s-life-Switching-between-the-perspectives-of-Lily-and-Atlas-%C2%A0It-Starts-with-Us%C2%A0picks-up-right-where-the-epilogue-for-the-bestselling-phenomenon%C2%A0It-Ends-with-Us%C2%A0left-off-Revealing-more-about-Atlas%E2%80%99s-past-and-following-Lily-as-she-embraces-a-second-chance-at-true-love-while-navigating-a-jealous-ex-husband-it-proves-that-%E2%80%9Cno-one-delivers-an-emotional-read-like-Colleen-Hoover%E2%80%9D-Anna-Todd-%C2%A0bestselling-author-%C2%A0" target="_blank"><i class="icon-pi"></i></a></li>
# </ul>
# </div>
# <div class="item-tools">
# <div class="checkout-tools">
# <div class="copy-content visible-md" data-target=".item-block .rating-wrap"></div>
# <div class="price-info-wrap">
# <div class="item-info-wrap">
# <div class="copy-content visible-md" data-target=".meta-info"></div>
# <div class="copy-content visible-md" data-target=".author-info"></div>
# <div class="hidden-xs hidden-sm">
# <div class="price item-price-wrap">
# <span class="sale-price">19,14 €</span>
# </div>
# </div>
# <div class="copy-content visible-md visible-xs visible-sm" data-target=".formats-wrap"></div>
# <div class="free-delivery-text">
# <i class="icon-rocket"></i>
# <p>Envío gratis</p>
# </div>
# <div class="gst-disclaimer" id="brexit_no_fee_message">
# <i class="icon-check"></i>
# <p>El precio incluye IVA/impuestos de importación para envíos a la UE</p>
# </div>
# <div class="availability-text">
# <i class="icon-check"></i>
# <div class="edd-availability-text">
# <p>Disponible. Entrega estimada a Spain en 9-14 días laborables.</p>
# <br/>
# <a class="edd-help-page-link" href="/es/help/topic/HelpId/2/When-will-my-order-arrive" target="_blank">
#                                                                         ¿La dirección de tu pedido no está en Spain? Click <span class="edd-help-page-link-here">aquí.<span></span></span></a>
# <br/>
# </div>
# </div>
# </div>
# </div>
# <div class="btn-wrap">
# <div class="copy-content visible-xs visible-sm" data-target=".item-price-wrap"></div>
# <a class="btn btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398518179" data-price="19.14" data-show-related="true" href="/es/basket/addisbn/isbn13/9781398518179">
#                                             Añadir a la cesta<input id="isOmnibusApplicable" type="hidden"/>
# </a>
# <a class="btn btn-grey add-to-wishlist" data-isbn="9781398518179" href="/es/account/wishlistItemUpdate?mainAction=add&amp;isbn13=9781398518179" rel="nofollow">
#                                     Añadir a la Lista de deseos</a>
# <div class="copy-content visible-xs visible-sm" data-target=".social-wrap"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="item-description">
# <h2>Descripción</h2>
# <div class="item-excerpt trunc" data-height="230" itemprop="description">
#
#                             Before It Ends with Us, it started with Atlas. Colleen Hoover tells fan favourite Atlas' side of the story and shares what comes next in this long-anticipated sequel to the #1 Sunday Times bestseller It Ends with Us.<br/>
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script>
# <div class="hero-quick-promo-wrap">
# <h2 class="hero-quick-promo-title"><a href="https://www.bookdepository.com/spanish">¡Descubre Miles de Libros en Español!</a></h2>
# <div class="hero-quick-promo-container">
# <div class="img-container">
# <img src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/content/COUNTRY_1112.jpg"/>
# </div>
# <div class="text-container">
# <a href="https://www.bookdepository.com/spanish">Tenemos más de <strong>800.000 libros </strong> en Español!!</a>
# </div>
# </div>
# </div>
# <div class="biblio-wrap">
# <div class="biblio-info-wrap">
# <h2 class="biblio-title">
#                             Detalles del producto</h2>
# <ul class="biblio-info">
# <li>
# <label>Formato</label>
# <span>
#                                 Paperback
#                                     | <span itemprop="numberOfPages">336 páginas
# </span>
# </span>
# </li>
# <li>
# <label>Dimensiones</label>
# <span>
#                                 153
#                                     x 234
#                                     x 21mm
#
#                                     | 380g
#                                 </span>
# </li>
# <li>
# <label>Fecha de publicación</label>
# <span itemprop="datePublished">18 Oct 2022</span>
# </li>
# <li>
# <label>Editorial</label>
# <span itemprop="publisher" itemscope="Simon &amp; Schuster Ltd" itemtype="http://schema.org/Organization">
# <a href="/es/publishers/Simon-Schuster-Ltd" itemprop="url">
# <span itemprop="name">
#                                         Simon &amp; Schuster Ltd</span>
# </a>
# </span>
# </li>
# <li>
# <label>Ciudad/País de publicación</label>
# <span>
#                                 London, United Kingdom</span>
# </li>
# <li>
# <label>Idioma</label>
# <span>
#                                 English</span>
# </li>
# <li>
# <label>Nota de la edición</label>
# <span>Export/Airside</span>
# </li>
# <li>
# <label>ISBN10</label>
# <span>1398518174</span>
# </li>
# <li>
# <label>ISBN13</label>
# <span itemprop="isbn">9781398518179</span>
# </li>
# <li>
# <label>Ranking en los libros más vendidos</label>
# <span>
#                                 4</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="detail-page-carousel-wrap">
# </div><ol class="breadcrumb category-footer">
# <li class="title">Categorías:</li>
# <li>
# <a href="/es/category/333/Fiction-Books">
#                                         Fiction Books</a>
# </li>
# <li>
# <a href="/es/category/334/Contemporary-Fiction">
#                                         Contemporary Fiction</a>
# </li>
# <li>
# <a href="/es/category/358/Romance">
#                                         Romance</a>
# </li>
# <li>
# <a href="/es/category/2630/Romance-Books">
#                                         Romance Books</a>
# </li>
# <li>
# <a href="/es/category/359/Adult-Contemporary-Romance">
#                                         Adult &amp; Contemporary Romance</a>
# </li>
# <li>
# <a href="/es/category/2631/Adult-Contemporary-Romance">
#                                         Adult &amp; Contemporary Romance</a>
# </li>
# <li>
# <a href="/es/category/644/Poverty-Unemployment">
#                                         Poverty  &amp; Unemployment</a>
# </li>
# <li class="active">
# <a href="/es/category/2771/Safety-Home">
#                                         Safety In The Home</a>
# </li>
# </ol>
# <div class="item-annotation-wrap" id="item-annotation">
# <div class="item-annotation">
# <h2>About Colleen Hoover</h2>
# <div class="block text-block trunc" data-height="100">
#                                     Colleen Hoover is the #1 New York Times bestselling author of more than twenty-three novels, including It Ends with Us, All Your Perfects, Ugly Love, and Verity. In 2015, Colleen and her family founded a non-profit called The Bookworm Box, a bookstore and monthly book-subscription service that has donated over $1,000,000 to various charities to date. Colleen lives in Texas with her husband and their three boys. For more information, please visit ColleenHoover.com.<br/>
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# </div>
# <div class="rating-distribution-wrap">
# <div class="rating-distribution" id="rating-distribution">
# <h2>Opiniones de clientes</h2>
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# </div>
# <span class="rating-count">
#                 (2,157 opiniones)</span>
# <div itemprop="ratingValue">
#                 4.77 de 5 estrellas</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         5</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="88.54891052387576"></span>
# </span>
#
#                     89% (1,910)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         4</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="5.9341678256838195"></span>
# </span>
#
#                     6% (128)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         3</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="2.132591562355123"></span>
# </span>
#
#                     2% (46)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         2</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="0.3708854891052387"></span>
# </span>
#
#                     0% (8)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         1</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="3.013444598980065"></span>
# </span>
#
#                     3% (65)</div>
# </div>
# </div>
# <div class="ratings-credit-wrap">
# <div class="ratings-credit">
#                             Opiniones de clientes de <span id="goodreads-credit"> Goodreads</span></div>
# <div class="goodreads-credit-extended">
# <a class="exit-to-goodreads" href="/es/external/GR/60471103" target="_blank">Goodreads</a> es el sitio más grande del mundo para lectores con más de 50 millones de opiniones. Te mostramos millones de opiniones de clientes de Goodreads en nuestro sitio web para ayudarte a seleccionar tu siguiente libro.<span class="goodreads-close">
#                         Cerrar</span>
# <span class="goodreads-close-x">
#                          X</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/es/newsletter/add">
# <div class="form-group">
# <input aria-label="Dirección de correo electrónico para suscribirte a nuestro Newsletter" class="form-control" name="newsletterEmailAddress" placeholder="" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                                 Sign up now
#                             </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-social-wrap">
# <h4>
#             Síguenos</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Descubre</h4>
# <ul>
# <li><a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/sitemap">
#                             Mapa del sitio</a></li>
# <li><a href="/es/bookmarks">
#                             Marcapáginas</a></li>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                     Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>¿En qué podemos ayudarte?</h4>
# <ul>
# <li>
# <a href="/es/help" rel="nofollow">
#                                 Ayuda</a>
# </li>
# <li>
# <a href="/es/contactus">
#                                 Contáctanos</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 ¿Dónde está mi pedido? </a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Envíos internacionales</a>
# </li>
# <li>
# <a href="/es/cancelorder" rel="nofollow">
#                                 Cancelar mi pedido</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                 Devolver mi pedido</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Trabaja con nosotros</h4>
# <ul>
# <li><a href="/es/affiliate">
#                             Afiliados</a></li>
# <li><a href="/es/jobs">
#                             Trabajar en Book Depository</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Información importante</h4>
# <ul>
# <li>
# <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Quejas</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Política de privacidad</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Términos y Condiciones </a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                     Iniciar sesión/Crear cuenta</a></li>
# <li><a href="/es/track">
#                             Mis pedidos</a></li>
# <li><a href="/es/contactus">
#                             Contáctanos</a></li>
# <li><a href="/es/help">
#                             Ayuda</a></li>
# <li><a href="/es/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Términos y Condiciones </a></li>
# <li><a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Política de privacidad</a></li>
# <li><a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>Aceptamos los siguientes métodos de pago </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-5', requestTime='0.03 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='2.138.111.2', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Oct 11 09:05:30 UTC 2022, cacheEnabled=true}}">
#                         © 2022
#                         The Book Depository Ltd.UK<br/>Número de registro de la empresa: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.35/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Comprar","bd_js_too_long_for_shipping_label":"Eso es demasiado largo para nuestras etiquetas de envío","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Eso es demasiado largo","bd_js_could_not_find_address_try_again":"No pudimos encontrar la dirección. Inténtalo de nuevo","bd_saving_percent_off":"Ahorra&lt;br&gt;{0}%","bd_js_total_basket_count":"{0, plural, one {Tienes &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;producto&lt;/span&gt;&lt;/b&gt; en el carrito} other {Tienes &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;productos&lt;/span&gt;&lt;/b&gt; en el carrito}}","bd_js_total_cost":"Costo total: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"mostrar menos","bd_js_item_added_to_your_basket":"Se agregó el producto en el carrito","bd_rrp":"PVPR","bd_link_prefix":"/es","bd_js_unable_get_address_enter_manually":"No podemos obtener la dirección. Ingrésala manualmente:","bd_js_keep_typing_to_refine_search_results":"Sigue escribiendo para ajustar los resultados de búsqueda","bd_js_top_categories":"Categorías principales","bd_price_save":"Ahorra {0}","bd_js_name_only_letters":"El nombre completo solo puede contener letras","bd_js_show_more":"mostrar más","bd_js_enter_valid_email_address":"Ingresa una dirección de correo electrónico válida","bd_js_enter_address_manually":"Ingresar la dirección manualmente","bd_js_more_categories":"Más categorías","bd_30_day_low_price_carousel":"Más bajo","bd_js_continue_shopping":"Seguir comprando","bd_js_account_and_help":"Cuenta y ayuda","bd_js_basket_checkout":"Carrito/proceder al pago","bd_add_to_basket":"Añadir a la cesta","bd_js_enter_first_last_name":"Ingresa un nombre y apellido","bd_js_please_enter_your":"Ingresa tu"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# Obtenemos el titulo del libro

# %%
name = soup_libro.find('h1').text
print(name)
# Out:
# It Starts with Us : the highly anticipated sequel to IT ENDS WITH US

# %% [markdown]
# El rating

# %%
# rating = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[5].text.split(' ')[-1].replace(',','.')
# rating = float(rating)
# rating

# %%
rating = soup_libro.find('span', attrs={'itemprop':'ratingValue'}).text.split(' ')[-1].replace(',','.')
rating
# Out:
# '4.77'

# %% [markdown]
# Cantidad de votaciones para el rating

# %%
# rating_count = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[-1].text.split(' ')[-6].replace('(','').replace('.','')
# rating_count = int(rating_count)
# rating_count

# %%
rating_count = soup_libro.find('span', class_='rating-count').text.strip()[1:-1].split(" ")[0].replace(',','')
rating_count = int(rating_count)
rating_count
# Out:
# 2157

# %% [markdown]
# Tipo de formato

# %%
formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text
formats
# Out:
# 'Paperback'

# %% [markdown]
# Autor

# %%
author1 = soup_libro.find("span", attrs={'itemprop':'name'}).text.strip()
author1
# Out:
# 'Colleen Hoover'

# %%
# author = soup_libro.find(class_ = 'item-annotation-wrap')('h2')
# author

# %% [markdown]
# Precio

# %%
price = float(soup_libro.find(class_ = 'sale-price').text.split(' ')[0].replace(',','.'))
price
# Out:
# 19.14

# %% [markdown]
# Url de la portada

# %%
imagen = soup_libro.find(class_ = 'book-img')['src']
imagen
# Out:
# 'https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/3985/9781398518179.jpg'

# %% [markdown]
# Ahora lo automatizamos para hacer un web scraping

# %%
pages = np.arange(1, 2)
count = 1
lista_libros = []

for page in pages:
    
    URL = 'https://www.bookdepository.com/es/bestsellers?page=' + str(page)
    r = requests.get(URL)
    soup = bs(r.text, 'lxml')
    libros_grid = soup.find_all(class_='item-img')
    
    count_libro = 1 # para el print de seguimiento de descarga
    
    for libro in libros_grid:
        # Print de seguimiento de descarga:
        print('Libro {} de {}, pag {}/{}'.format(
            count_libro, len(libros_grid), page, len(pages)))

        URL_libro = libro.find('a')['href']
        r = requests.get('https://www.bookdepository.com/' + URL_libro)
        soup_libro = bs(r.text, 'lxml')
        
        id_libro = 'lb_' + str(count)
        
        name = soup_libro.find('h1').text   
        try:
            price = float(soup_libro.find(class_ = 'sale-price').text.split(' ')[0].replace(',','.'))

        except:
            price = None

        try :
            author = soup_libro.find("span", attrs={'itemprop':'name'}).text.strip()

        except:
            author = None

        formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text

        try:
            rating = soup_libro.find('span', attrs={'itemprop':'ratingValue'}).text.split(' ')[-1].replace(',','.')
            rating = float(rating)
        
        except:
            rating = None
        
        try:    
            rating_count = soup_libro.find('span', class_='rating-count').text.strip()[1:-1].split(" ")[0].replace(',','')
            rating_count = int(rating_count)
        
        except:
            rating_count = None

        imagen = soup_libro.find(class_ = 'book-img')['src']

        data = {"id_libro": id_libro,
                "name": name,
                "price": price,
                "author": author,
                "format": formats,
                "rating": rating,
                "rating_count": rating_count,
                "imagen": imagen}

        lista_libros.append(data)
        
        # Pasamos al siguiente id
        count += 1
        count_libro += 1
# Out:
# Libro 1 de 30, pag 1/1
# Libro 2 de 30, pag 1/1
# Libro 3 de 30, pag 1/1
# Libro 4 de 30, pag 1/1
# Libro 5 de 30, pag 1/1
# Libro 6 de 30, pag 1/1
# Libro 7 de 30, pag 1/1
# Libro 8 de 30, pag 1/1
# Libro 9 de 30, pag 1/1
# Libro 10 de 30, pag 1/1
# Libro 11 de 30, pag 1/1
# Libro 12 de 30, pag 1/1
# Libro 13 de 30, pag 1/1
# Libro 14 de 30, pag 1/1
# Libro 15 de 30, pag 1/1
# Libro 16 de 30, pag 1/1
# Libro 17 de 30, pag 1/1
# Libro 18 de 30, pag 1/1
# Libro 19 de 30, pag 1/1
# Libro 20 de 30, pag 1/1
# Libro 21 de 30, pag 1/1
# Libro 22 de 30, pag 1/1
# Libro 23 de 30, pag 1/1
# Libro 24 de 30, pag 1/1
# Libro 25 de 30, pag 1/1
# Libro 26 de 30, pag 1/1
# Libro 27 de 30, pag 1/1
# Libro 28 de 30, pag 1/1
# Libro 29 de 30, pag 1/1
# Libro 30 de 30, pag 1/1

# %% [markdown]
# ---------------

# %%
df = pd.DataFrame(lista_libros)
df
# Out:
#    id_libro                                               name  price  \
# 0      lb_1                   TommyInnit Says...The Quote Book  19.39
# 1      lb_2      Courtiers : The Hidden Power Behind the Crown  23.06
# 2      lb_3  Verity : The thriller that will capture your h...  13.64
# 3      lb_4  It Starts with Us : the highly anticipated seq...  19.14
# 4      lb_5                               I'm Glad My Mom Died  23.40
# 5      lb_6  It Ends With Us: The most heartbreaking novel ...  13.64
# 6      lb_7  Loss : Poems to better weather the many waves ...  12.68
# 7      lb_8  Life : Poems to help navigate life's many twis...  12.68
# 8      lb_9  Atomic Habits : the life-changing million-copy...  20.75
# 9     lb_10  Seven Husbands of Evelyn Hugo : The Sunday Tim...  12.58
# 10    lb_11  The Invisible Life of Addie LaRue - Illustrate...  22.84
# 11    lb_12  Love : Poems to bolster every heart that ever ...  12.68
# 12    lb_13                                          Ugly Love  12.83
# 13    lb_14  The Secret History : From the Pulitzer Prize-w...  14.99
# 14    lb_15                        Before the Coffee Gets Cold  13.80
# 15    lb_16                            Where the Crawdads Sing  12.60
# 16    lb_17                                       Twisted Love  12.21
# 17    lb_18                      Always Room for Christmas Pud  17.08
# 18    lb_19                                       Twisted Lies  12.84
# 19    lb_20  Rooms of Wonder : Step Inside this Magical Col...  19.82
# 20    lb_21  It Ends With Us - Special Edition : The emotio...  18.75
# 21    lb_22                                If We Were Villains  14.41
# 22    lb_23           12 Rules for Life : An Antidote to Chaos  15.14
# 23    lb_24  The Woks of Life : Recipes to Know and Love fr...  39.00
# 24    lb_25                                    Saga, Volume 10  17.48
# 25    lb_26  The Body Keeps the Score : Mind, Brain and Bod...  17.15
# 26    lb_27  Things We Never Got Over : the TikTok bestsell...  12.59
# 27    lb_28                                         November 9  13.29
# 28    lb_29       Red, White & Royal Blue: Collector's Edition    NaN
# 29    lb_30  The Thursday Murder Club : (The Thursday Murde...  13.74
#
#                  author     format  rating  rating_count  \
# 0            Tom Simons   Hardback     NaN           NaN
# 1         Valentine Low   Hardback     NaN           NaN
# 2        Colleen Hoover  Paperback    4.43      823944.0
# 3        Colleen Hoover  Paperback    4.77        2157.0
# 4      Jennette McCurdy   Hardback    4.65         102.0
# 5        Colleen Hoover  Paperback    4.42     1178344.0
# 6        Donna Ashworth   Hardback     NaN           NaN
# 7        Donna Ashworth   Hardback     NaN           NaN
# 8           James Clear  Paperback    4.38      398537.0
# 9   Taylor Jenkins Reid  Paperback    4.48     1179179.0
# 10          V.E. Schwab   Hardback     NaN           NaN
# 11       Donna Ashworth   Hardback     NaN           NaN
# 12       Colleen Hoover  Paperback    4.25      652795.0
# 13          Donna Tartt  Paperback    4.14      446669.0
# 14  Toshikazu Kawaguchi  Paperback    3.75      103849.0
# 15          Delia Owens  Paperback    4.45     1780708.0
# 16            Ana Huang  Paperback    3.80       84556.0
# 17          Aunty Donna   Hardback     NaN           NaN
# 18            Ana Huang  Paperback    4.54         305.0
# 19      Johanna Basford  Paperback    5.00           1.0
# 20       Colleen Hoover  Paperback     NaN           NaN
# 21            M. L. Rio  Paperback    4.22       82472.0
# 22   Jordan B. Peterson  Paperback    3.94      161078.0
# 23           Bill Leung   Hardback     NaN           NaN
# 24      Brian K Vaughan  Paperback    4.58         148.0
# 25  Bessel van der Kolk  Paperback    4.48       90049.0
# 26           Lucy Score  Paperback    4.35          20.0
# 27       Colleen Hoover  Paperback    4.33      372881.0
# 28      Casey McQuiston   Hardback    4.18      536997.0
# 29        Richard Osman  Paperback    3.95      214784.0
#
#                                                imagen
# 0   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 1   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 2   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 3   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 4   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 5   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 6   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 7   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 8   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 9   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 10  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 11  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 12  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 13  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 14  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 15  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 16  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 17  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 19  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 20  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 21  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 22  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 23  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 24  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 25  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 26  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 27  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 28  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 29  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
